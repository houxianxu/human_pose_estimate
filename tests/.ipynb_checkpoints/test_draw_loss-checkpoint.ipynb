# %% [markdown]
# ## Test the my_scripts/data_utils.py function

# %%
# A bit of setup
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
#   File "<ipython-input-9-a552f357850f>", line 6
#     cd ..
#         ^
# SyntaxError: invalid syntax

# %%
# Revert back to the main op
cd ..
# Out:
# /Users/houxianxu/Documents/PhD/Implementation/deeppose

# %%
from my_scripts.draw_loss import draw_loss_from_list
train_loss = range(1, 100)
val_loss = range(101, 200)
outfile = 'tests/loss.jpg'
draw_loss_from_list(train_loss, val_loss, outfile)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-61959c740464> in <module>()
# ----> 1 from my_scripts.draw_loss import draw_loss_from_list
#       2 train_loss = range(1, 100)
#       3 val_loss = range(101, 200)
#       4 outfile = 'tests/loss.jpg'
#       5 draw_loss_from_list(train_loss, val_loss, outfile)
#
# ImportError: No module named my_scripts.draw_loss

# %%
# show the loss decreasing with epoch
from IPython.display import Image
Image(filename=outfile, width=800)

# %%
ls
# Out:
# chainer/              loss_history.png      test_transform.py
# learn_chainer.ipynb   test_draw_loss.ipynb  val_loss.jpg
# loss.jpg              test_flic_dataset.py  val_loss.png
# loss.png              test_lsp_dataset.py
# loss_history.jpg      test_mpii_dataset.py

# %%
# Out:
# /Users/houxianxu/Documents/PhD/Implementation/deeppose

# %%
cd -
# Out:
# /Users/houxianxu/Documents/PhD/Implementation/deeppose/tests

# %%
cd ..
# Out:
# /Users/houxianxu/Documents/PhD/Implementation/deeppose
