# %% [markdown]
# ## Test the my_scripts/data_utils.py function

# %%
# A bit of setup
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# a

# %%
from my_scripts.draw_loss import draw_loss_from_list
train_loss = range(1, 100)
val_loss = range(101, 200)
outfile = 'tests/loss.jpg'
draw_loss_from_list(train_loss, val_loss, outfile)
# Out:
# Saving 11.0 x 8.0 in image.

# %%
# show the loss decreasing with epoch
from IPython.display import Image
Image(filename=outfile, width=800)
